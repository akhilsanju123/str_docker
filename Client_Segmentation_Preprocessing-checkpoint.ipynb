# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from sklearn.impute import KNNImputer
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv(r"/content/drive/MyDrive/Client_Segmentation/ecommerce.csv", encoding='unicode_escape')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
df.StockCode.nunique()
# Out:
# 4070

# %%
country_mapping = {
    'United Kingdom': 1,
    'France': 2,
    'Australia': 3,
    'Netherlands': 4,
    'Germany': 5,
    'Norway': 6,
    'EIRE': 7,
    'Switzerland': 8,
    'Spain': 9,
    'Poland': 10,
    'Portugal': 11,
    'Italy': 12,
    'Belgium': 13,
    'Lithuania': 14,
    'Japan': 15,
    'Iceland': 16,
    'Channel Islands': 17,
    'Denmark': 18,
    'Cyprus': 19,
    'Sweden': 20,
    'Austria': 21,
    'Israel': 22,
    'Finland': 23,
    'Bahrain': 24,
    'Greece': 25,
    'Hong Kong': 26,
    'Singapore': 27,
    'Lebanon': 28,
    'United Arab Emirates': 29,
    'Saudi Arabia': 30,
    'Czech Republic': 31,
    'Canada': 32,
    'Unspecified': 33,
    'Brazil': 34,
    'USA': 35,
    'European Community': 36,
    'Malta': 37,
    'RSA': 38
}

df['Country_value'] = df['Country'].map(country_mapping)

# %%
Unit_Price = abs(df.UnitPrice)
quantity1 = abs(df.Quantity)
df.drop(columns=['UnitPrice', 'Quantity'], axis=1, inplace=True)
df['Quantity'] = quantity1
df['UnitPrice'] = Unit_Price

# %%
df.describe()
# Out:
#           CustomerID  Country_value       Quantity      UnitPrice
# count  406829.000000  541909.000000  541909.000000  541909.000000
# mean    15287.690570       1.615585      11.340487       4.692766
# std      1713.600303       2.849583     217.995482      96.755927
# min     12346.000000       1.000000       1.000000       0.000000
# 25%     13953.000000       1.000000       1.000000       1.250000
# 50%     15152.000000       1.000000       3.000000       2.080000
# 75%     16791.000000       1.000000      10.000000       4.130000
# max     18287.000000      38.000000   80995.000000   38970.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   InvoiceNo      541909 non-null  object
#  1   StockCode      541909 non-null  object
#  2   Description    540455 non-null  object
#  3   InvoiceDate    541909 non-null  object
#  4   CustomerID     406829 non-null  float64
#  5   Country        541909 non-null  object
#  6   Country_value  541909 non-null  int64
#  7   Quantity       541909 non-null  int64
#  8   UnitPrice      541909 non-null  float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 37.2+ MB

# %%
df.isnull().sum()
# Out:
# InvoiceNo             0
# StockCode             0
# Description        1454
# InvoiceDate           0
# CustomerID       135080
# Country               0
# Country_value         0
# Quantity              0
# UnitPrice             0
# dtype: int64

# %%
df = df.dropna(subset=['Description'])

# %%
imputer = KNNImputer(n_neighbors=5)
df['CustomerID'] = imputer.fit_transform(df.CustomerID.values.reshape(-1, 1))

# %%
df.isnull().sum()
# Out:
# InvoiceNo        0
# StockCode        0
# Description      0
# InvoiceDate      0
# CustomerID       0
# Country          0
# Country_value    0
# Quantity         0
# UnitPrice        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 540455 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   InvoiceNo      540455 non-null  object
#  1   StockCode      540455 non-null  object
#  2   Description    540455 non-null  object
#  3   InvoiceDate    540455 non-null  object
#  4   CustomerID     540455 non-null  float64
#  5   Country        540455 non-null  object
#  6   Country_value  540455 non-null  int64
#  7   Quantity       540455 non-null  int64
#  8   UnitPrice      540455 non-null  float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 41.2+ MB

# %%
df.describe()
# Out:
#           CustomerID  Country_value       Quantity      UnitPrice
# count  540455.000000  540455.000000  540455.000000  540455.000000
# mean    15287.690570       1.617241      11.225373       4.705391
# std      1486.741898       2.853234     217.930089      96.885686
# min     12346.000000       1.000000       1.000000       0.000000
# 25%     14364.000000       1.000000       1.000000       1.250000
# 50%     15287.690570       1.000000       3.000000       2.080000
# 75%     16261.000000       1.000000      10.000000       4.130000
# max     18287.000000      38.000000   80995.000000   38970.000000

# %%
df['Date']= pd.to_datetime(df['InvoiceDate'])
df['CustomerID'] = np.round(df['CustomerID']).astype(int)
df.drop(columns=['InvoiceDate'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 540455 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   InvoiceNo      540455 non-null  object
#  1   StockCode      540455 non-null  object
#  2   Description    540455 non-null  object
#  3   CustomerID     540455 non-null  int64
#  4   Country        540455 non-null  object
#  5   Country_value  540455 non-null  int64
#  6   Quantity       540455 non-null  int64
#  7   UnitPrice      540455 non-null  float64
#  8   Date           540455 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 41.2+ MB

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  CustomerID  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       17850
# 1    536365     71053                  WHITE METAL LANTERN       17850
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       17850
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       17850
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       17850
#
#           Country  Country_value  Quantity  UnitPrice                Date
# 0  United Kingdom              1         6       2.55 2010-12-01 08:26:00
# 1  United Kingdom              1         6       3.39 2010-12-01 08:26:00
# 2  United Kingdom              1         8       2.75 2010-12-01 08:26:00
# 3  United Kingdom              1         6       3.39 2010-12-01 08:26:00
# 4  United Kingdom              1         6       3.39 2010-12-01 08:26:00

# %%
numeric_cols = ["Quantity", "UnitPrice"]
categorical_cols = ["Country", 'StockCode']

# %%
le = LabelEncoder()
df.StockCode = le.fit_transform(df.StockCode)

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'CustomerID', 'Country',
#        'Country_value', 'Quantity', 'UnitPrice', 'Date'],
#       dtype='object')

# %%
df.to_csv('Updated_file.csv', index=False)
